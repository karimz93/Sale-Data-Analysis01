# %% [markdown]
# # Data Analysis Via Pandas and Matplotlib Libraries:
# #### This project is part of a learning process that I am attempting in order to understand some of the basic elements of data analysis within a buisness setting.
#
# We will use Pyhton Pandas and Matplotlib to analyze and answer buisness-driven questions about a year long worth of sales. Our data contains hundreds of thousands of electronic devices store purchases broken down by: month, product type, cost, purchase address, quantity, etc.

# %% [markdown]
# #### Import Essential Libraries:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from functools import reduce

# %% [markdown]
# #### Import Data For 12 Months

# %%
df1 = pd.read_csv("Untitled folder 1/Sales_January_2019.csv")
df2 = pd.read_csv("Untitled folder 1/Sales_February_2019.csv")
df3 = pd.read_csv("Untitled folder 1/Sales_March_2019.csv")
df4 = pd.read_csv("Untitled folder 1/Sales_April_2019.csv")
df5 = pd.read_csv("Untitled folder 1/Sales_May_2019.csv")
df6 = pd.read_csv("Untitled folder 1/Sales_June_2019.csv")
df7 = pd.read_csv("Untitled folder 1/Sales_July_2019.csv")
df8 = pd.read_csv("Untitled folder 1/Sales_August_2019.csv")
df9 = pd.read_csv("Untitled folder 1/Sales_September_2019.csv")
df10 = pd.read_csv("Untitled folder 1/Sales_October_2019.csv")
df11 = pd.read_csv("Untitled folder 1/Sales_November_2019.csv")
df12 = pd.read_csv("Untitled folder 1/Sales_December_2019.csv")

# %% [markdown]
# #### Segment data by each year quarter and merge into 4 distinct dataframes:
#
# * Data for an entire year has been uploaded into the Jupyter Notebook.We will use 1st, 2nd, 3rd, and 4th quarters to reduce the size of the overall dataframe, which could not be implemeted in the jupyter notebook to to size limitations.

# %%
df_1st_quarter = [df1, df2, df3] # 1st Quarter of 2019
df_2nd_quarter = [df4, df5, df6] # 2nd Quarter of 2019
df_3rd_quarter = [df7, df8, df9] # 3rd Quarter of 2019
df_4th_quarter = [df10, df11, df12] # 4th Quarter of 2019

df_merged1= reduce(lambda left,right: pd.merge(left, right, how = 'outer'), df_1st_quarter)
df_merged2= reduce(lambda left,right: pd.merge(left, right, how = 'outer'), df_2nd_quarter)
df_merged3= reduce(lambda left,right: pd.merge(left, right, how = 'outer'), df_3rd_quarter)
df_merged4= reduce(lambda left,right: pd.merge(left, right, how = 'outer'), df_4th_quarter)

# %%
df_merged1.head() # Pull-up 1st five rows of the dataframe
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
df_merged1.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
print("Data For First Quarter: \n")
print(df_merged1.count())
print("Data For Second Quarter: \n")
print(df_merged2.count())
print("Data For Thrid Quarter: \n")
print(df_merged3.count())
print("Data For Fourth Quarter: \n")
print(df_merged4.count())
# Out:
# Data For First Quarter:
#
# Order ID            46901
# Product             46901
# Quantity Ordered    46901
# Price Each          46901
# Order Date          46901
# Purchase Address    46901
# dtype: int64
# Data For Second Quarter:
#
# Order ID            74964
# Product             74964
# Quantity Ordered    74964
# Price Each          74964
# Order Date          74964
# Purchase Address    74964
# dtype: int64
# Data For Thrid Quarter:
#
# Order ID            53347
# Product             53347
# Quantity Ordered    53347
# Price Each          53347
# Order Date          53347
# Purchase Address    53347
# dtype: int64
# Data For Fourth Quarter:
#
# Order ID            119877
# Product             119877
# Quantity Ordered    119877
# Price Each          119877
# Order Date          119877
# Purchase Address    119877
# dtype: int64

# %% [markdown]
# ### Cleaning Data:

# %% [markdown]
# #### Drop rows of NaN from each dataframe:

# %%
nan_df1 = df_merged1[df_merged1.isna().any(axis=1)]
nan_df1.head()

df_merged1 = df_merged1.dropna(how = 'all')
df_merged1.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
nan_df2 = df_merged2[df_merged2.isna().any(axis=1)]
nan_df1.head()

df_merged2 = df_merged2.dropna(how = 'all')
df_merged2.head()
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 121777   176559  Bose SoundSport Headphones                1      99.99
# 121778   176560                Google Phone                1        600
# 121779   176560            Wired Headphones                1      11.99
# 121780   176561            Wired Headphones                1      11.99
#
#             Order Date                      Purchase Address
# 0       04/19/19 08:46          917 1st St, Dallas, TX 75001
# 121777  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 121778  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 121779  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 121780  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
nan_df3 = df_merged3[df_merged3.isna().any(axis=1)]
nan_df3.head()

df_merged3 = df_merged3.dropna(how = 'all')
df_merged3.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   222910  Apple Airpods Headphones                1        150
# 1   222911             Flatscreen TV                1        300
# 2   222912     AA Batteries (4-pack)                1       3.84
# 3   222913     AA Batteries (4-pack)                1       3.84
# 4   222914    AAA Batteries (4-pack)                5       2.99
#
#        Order Date                  Purchase Address
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101

# %%
nan_df4 = df_merged4[df_merged4.isna().any(axis=1)]
nan_df4.head()

df_merged4 = df_merged4.dropna(how = 'all')
df_merged4.head()
# Out:
#   Order ID                 Product Quantity Ordered Price Each  \
# 0   259358  34in Ultrawide Monitor                1     379.99
# 1   259359  27in 4K Gaming Monitor                1     389.99
# 2   259360  AAA Batteries (4-pack)                2       2.99
# 3   259361        27in FHD Monitor                1     149.99
# 4   259362        Wired Headphones                1      11.99
#
#        Order Date                           Purchase Address
# 0  10/28/19 10:56            609 Cherry St, Dallas, TX 75001
# 1  10/28/19 17:26          225 5th St, Los Angeles, CA 90001
# 2  10/24/19 17:20       967 12th St, New York City, NY 10001
# 3  10/14/19 22:26  628 Jefferson St, New York City, NY 10001
# 4  10/07/19 16:10         534 14th St, Los Angeles, CA 90001

# %% [markdown]
# #### Find 'Or' and delete it from each dataframe:

# %%
df_merged1 = df_merged1[df_merged1["Order Date"].str[0:2] != 'Or']
df_merged2 = df_merged2[df_merged2["Order Date"].str[0:2] != 'Or']
df_merged3 = df_merged3[df_merged3["Order Date"].str[0:2] != 'Or']
df_merged4 = df_merged4[df_merged4["Order Date"].str[0:2] != 'Or']

# %% [markdown]
# ### Make columns of correct type:

# %%
# Convert Columns Data Types to Correct Data Types for Each DataFrame:

# DataFrame for First Yearly Quarter:
df_merged1["Quantity Ordered"] = df_merged1["Quantity Ordered"].astype("int32")
df_merged1["Price Each"] = df_merged1["Price Each"].astype("float")

df_merged1["Sales"] = df_merged1["Quantity Ordered"] * df_merged1["Price Each"]

df_merged1.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address   Sales
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301   11.99

# %%
# DataFrame for Second Yearly Quarter:
df_merged2["Quantity Ordered"] = df_merged2["Quantity Ordered"].astype("int32")
df_merged2["Price Each"] = df_merged2["Price Each"].astype("float")

df_merged2["Sales"] = df_merged2["Quantity Ordered"] * df_merged2["Price Each"]

# DataFrame for Third Yearly Quarter:
df_merged3["Quantity Ordered"] = df_merged3["Quantity Ordered"].astype("int32")
df_merged3["Price Each"] = df_merged3["Price Each"].astype("float")

df_merged3["Sales"] = df_merged3["Quantity Ordered"] * df_merged3["Price Each"]

# DataFrame for Fourth Yearly Quarter:
df_merged4["Quantity Ordered"] = df_merged4["Quantity Ordered"].astype("int32")
df_merged4["Price Each"] = df_merged4["Price Each"].astype("float")

df_merged4["Sales"] = df_merged4["Quantity Ordered"] * df_merged4["Price Each"]

df_merged4.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each  \
# 0   259358  34in Ultrawide Monitor                 1      379.99
# 1   259359  27in 4K Gaming Monitor                 1      389.99
# 2   259360  AAA Batteries (4-pack)                 2        2.99
# 3   259361        27in FHD Monitor                 1      149.99
# 4   259362        Wired Headphones                 1       11.99
#
#        Order Date                           Purchase Address   Sales
# 0  10/28/19 10:56            609 Cherry St, Dallas, TX 75001  379.99
# 1  10/28/19 17:26          225 5th St, Los Angeles, CA 90001  389.99
# 2  10/24/19 17:20       967 12th St, New York City, NY 10001    5.98
# 3  10/14/19 22:26  628 Jefferson St, New York City, NY 10001  149.99
# 4  10/07/19 16:10         534 14th St, Los Angeles, CA 90001   11.99

# %% [markdown]
# ## Augment data with additional month columns:

# %%
df_merged1["Month"] = df_merged1["Order Date"].str[0:2] # e.g. date 01/27/2019 pick 01 and so on for each Month column
df_merged2["Month"] = df_merged2["Order Date"].str[0:2]
df_merged3["Month"] = df_merged3["Order Date"].str[0:2]
df_merged4["Month"] = df_merged4["Order Date"].str[0:2]


df_merged1["Month"] = df_merged1["Month"].astype("int32") # Covert Month column to integer data type
df_merged2["Month"] = df_merged2["Month"].astype("int32")
df_merged3["Month"] = df_merged3["Month"].astype("int32")
df_merged4["Month"] = df_merged4["Month"].astype("int32")

# %%
df_merged4.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each  \
# 0   259358  34in Ultrawide Monitor                 1      379.99
# 1   259359  27in 4K Gaming Monitor                 1      389.99
# 2   259360  AAA Batteries (4-pack)                 2        2.99
# 3   259361        27in FHD Monitor                 1      149.99
# 4   259362        Wired Headphones                 1       11.99
#
#        Order Date                           Purchase Address   Sales  Month
# 0  10/28/19 10:56            609 Cherry St, Dallas, TX 75001  379.99     10
# 1  10/28/19 17:26          225 5th St, Los Angeles, CA 90001  389.99     10
# 2  10/24/19 17:20       967 12th St, New York City, NY 10001    5.98     10
# 3  10/14/19 22:26  628 Jefferson St, New York City, NY 10001  149.99     10
# 4  10/07/19 16:10         534 14th St, Los Angeles, CA 90001   11.99     10

# %% [markdown]
# #### Add a city column:

# %%
# Let's use .apply()
# Consider cities with duplicate names i.e look-up states as well:

def get_city(address):
    return address.split(",")[1] # Get city name

def get_state(address):
    return address.split(",")[2].split(' ')[1] # Get state and delete ZipCode

df_merged1["City"] = df_merged1["Purchase Address"].apply(lambda x: 
                                f"{get_city(x)} ({get_state(x)})")


df_merged1.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address   Sales  Month  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  700.00      1
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035   14.95      1
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016   23.98      1
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001  149.99      1
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301   11.99      1
#
#                   City
# 0          Boston (MA)
# 1        Portland (OR)
# 2   San Francisco (CA)
# 3     Los Angeles (CA)
# 4          Austin (TX)

# %%
def get_city(address):
    return address.split(",")[1]

def get_state(address):
    return address.split(",")[2].split(' ')[1]

df_merged2["City"] = df_merged2["Purchase Address"].apply(lambda x:
                                f"{get_city(x)} ({get_state(x)})")

df_merged2.head()
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 121777   176559  Bose SoundSport Headphones                 1       99.99
# 121778   176560                Google Phone                 1      600.00
# 121779   176560            Wired Headphones                 1       11.99
# 121780   176561            Wired Headphones                 1       11.99
#
#             Order Date                      Purchase Address   Sales  Month  \
# 0       04/19/19 08:46          917 1st St, Dallas, TX 75001   23.90      4
# 121777  04/07/19 22:30     682 Chestnut St, Boston, MA 02215   99.99      4
# 121778  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001  600.00      4
# 121779  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001   11.99      4
# 121780  04/30/19 09:27     333 8th St, Los Angeles, CA 90001   11.99      4
#
#                      City
# 0             Dallas (TX)
# 121777        Boston (MA)
# 121778   Los Angeles (CA)
# 121779   Los Angeles (CA)
# 121780   Los Angeles (CA)

# %%
def get_city(address):
    return address.split(",")[1]
def get_state(address):
    return address.split(",")[2].split(' ')[1]

df_merged3["City"] = df_merged3["Purchase Address"].apply(lambda x: 
                                f"{get_city(x)} ({get_state(x)})")

df_merged3.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   222910  Apple Airpods Headphones                 1      150.00
# 1   222911             Flatscreen TV                 1      300.00
# 2   222912     AA Batteries (4-pack)                 1        3.84
# 3   222913     AA Batteries (4-pack)                 1        3.84
# 4   222914    AAA Batteries (4-pack)                 5        2.99
#
#        Order Date                  Purchase Address   Sales  Month  \
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301  150.00      7
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101  300.00      7
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301    3.84      7
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301    3.84      7
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101   14.95      7
#
#             City
# 0   Atlanta (GA)
# 1   Seattle (WA)
# 2   Atlanta (GA)
# 3   Atlanta (GA)
# 4   Seattle (WA)

# %%
def get_city(address):
    return address.split(",")[1]

def get_state(address):
    return address.split(",")[2].split(' ')[1]

df_merged4["City"] = df_merged4["Purchase Address"].apply(lambda x: 
                                    f"{get_city(x)} ({get_state(x)})")

df_merged4.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each  \
# 0   259358  34in Ultrawide Monitor                 1      379.99
# 1   259359  27in 4K Gaming Monitor                 1      389.99
# 2   259360  AAA Batteries (4-pack)                 2        2.99
# 3   259361        27in FHD Monitor                 1      149.99
# 4   259362        Wired Headphones                 1       11.99
#
#        Order Date                           Purchase Address   Sales  Month  \
# 0  10/28/19 10:56            609 Cherry St, Dallas, TX 75001  379.99     10
# 1  10/28/19 17:26          225 5th St, Los Angeles, CA 90001  389.99     10
# 2  10/24/19 17:20       967 12th St, New York City, NY 10001    5.98     10
# 3  10/14/19 22:26  628 Jefferson St, New York City, NY 10001  149.99     10
# 4  10/07/19 16:10         534 14th St, Los Angeles, CA 90001   11.99     10
#
#                   City
# 0          Dallas (TX)
# 1     Los Angeles (CA)
# 2   New York City (NY)
# 3   New York City (NY)
# 4     Los Angeles (CA)

# %% [markdown]
# # Data Exploration!

# %% [markdown]
# #### Q1: What was the best month for sales? How much was earned that month?

# %% [markdown]
# ##### Adding a sales column:

# %%
df_merged1.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int32
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Sales               float64
# Month                 int32
# City                 object
# dtype: object

# %%
df_merged3.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   222910  Apple Airpods Headphones                 1      150.00
# 1   222911             Flatscreen TV                 1      300.00
# 2   222912     AA Batteries (4-pack)                 1        3.84
# 3   222913     AA Batteries (4-pack)                 1        3.84
# 4   222914    AAA Batteries (4-pack)                 5        2.99
#
#        Order Date                  Purchase Address   Sales  Month  \
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301  150.00      7
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101  300.00      7
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301    3.84      7
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301    3.84      7
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101   14.95      7
#
#             City
# 0   Atlanta (GA)
# 1   Seattle (WA)
# 2   Atlanta (GA)
# 3   Atlanta (GA)
# 4   Seattle (WA)

# %%
print(df_merged1.groupby("Month").sum())
print(df_merged2.groupby("Month").sum())
print(df_merged3.groupby("Month").sum())
print(df_merged4.groupby("Month").sum())
# Out:
#        Quantity Ordered  Price Each       Sales
# Month
# 1                 10862  1803264.98  1813586.44
# 2                 13449  2188884.72  2202022.42
# 3                 17005  2791207.83  2807100.38
# 4                    19     5167.43     5170.42
#        Quantity Ordered    Price Each         Sales
# Month
# 4                 20539  3.362504e+06  3.385500e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                    21  2.998490e+03  3.028380e+03
#        Quantity Ordered  Price Each       Sales
# Month
# 7                 16051  2629541.07  2644747.38
# 8                 13448  2230345.42  2244467.88
# 9                 13109  2084992.09  2097560.13
# 10                   22     3347.33     3353.31
#        Quantity Ordered    Price Each         Sales
# Month
# 1                    41  8.503400e+03  8.670290e+03
# 10                22681  3.712208e+06  3.733374e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %% [markdown]
# ##### We see that December was the best month for sales with about 4.6 million US Dollars... Let us visualize the sales result for each month in the year 2019:

# %%
results_Q1 = df_merged1.groupby("Month").sum()
results_Q2 = df_merged2.groupby("Month").sum()
results_Q3 = df_merged3.groupby("Month").sum()
results_Q4 = df_merged4.groupby("Month").sum()

# %%
firstQ = range(1,5)

plt.bar(firstQ, results_Q1["Sales"])
plt.xticks(firstQ)
plt.ylabel("Sales in USD ($)")
plt.xlabel("Month Number")
plt.show()

# %%
secondQ = range(4, 8)

plt.bar(secondQ, results_Q2["Sales"])
plt.xticks(secondQ)
plt.ylabel("Sales in USD ($)")
plt.xlabel("Month Number")
plt.show()

# %%
thirdQ = range(8, 12)

plt.bar(thirdQ, results_Q3["Sales"])
plt.xticks(thirdQ)
plt.ylabel("Sales in USD ($)")
plt.xlabel("Month Number")
plt.show()

# %%
fourthQ = range(9, 13)

plt.bar(fourthQ, results_Q4["Sales"])
plt.xticks(fourthQ)
plt.ylabel("Sales in USD ($)")
plt.xlabel("Month Number")
plt.show()

# %% [markdown]
# #### Q2. Which US city had the highest number of sales:

# %%
city_results_Q1 = df_merged1.groupby("City").sum()
city_results_Q2 = df_merged2.groupby("City").sum()
city_results_Q3 = df_merged3.groupby("City").sum()
city_results_Q4 = df_merged4.groupby("City").sum()

# %%
Rresult = [city_results_Q1, city_results_Q2, city_results_Q3, city_results_Q4]
Rresult
# Out:
# [                     Quantity Ordered  Price Each       Sales  Month
#  City
#   Atlanta (GA)                    3304   554513.35   557541.20   6396
#   Austin (TX)                     2217   349160.62   350923.75   4300
#   Boston (MA)                     4456   712555.02   716636.49   8512
#   Dallas (TX)                     3338   548402.22   551392.23   6357
#   Los Angeles (CA)                6632  1053384.85  1059757.88  12704
#   New York City (NY)              5519   927763.66   934845.09  10476
#   Portland (ME)                    560    82594.68    83070.58   1041
#   Portland (OR)                   2184   365936.93   368421.86   4205
#   San Francisco (CA)              9917  1665877.66  1673905.74  18977
#   Seattle (WA)                    3208   528335.97   531384.84   6188,
#                       Quantity Ordered  Price Each       Sales  Month
#  City
#   Atlanta (GA)                    4365   739299.15   743113.39  19171
#   Austin (TX)                     2858   474494.83   477400.00  12379
#   Boston (MA)                     5791   929480.48   936427.91  25032
#   Dallas (TX)                     4325   704596.27   708117.66  18903
#   Los Angeles (CA)                8735  1493208.95  1501350.12  38157
#   New York City (NY)              7298  1198310.19  1206880.73  31738
#   Portland (ME)                    737   130089.37   130540.58   3264
#   Portland (OR)                   3051   508637.51   510736.74  13170
#   San Francisco (CA)             13110  2186495.50  2203002.03  57200
#   Seattle (WA)                    4210   698040.57   701368.05  18310,
#                       Quantity Ordered  Price Each       Sales  Month
#  City
#   Atlanta (GA)                    3347   549346.33   552313.02  23785
#   Austin (TX)                     2349   380862.74   382625.23  16523
#   Boston (MA)                     4635   773674.10   779179.14  32375
#   Dallas (TX)                     3388   551224.36   554289.54  23846
#   Los Angeles (CA)                6702  1089254.83  1094531.60  47549
#   New York City (NY)              5684   954084.22   960072.37  40348
#   Portland (ME)                    561    96432.60    97177.30   4019
#   Portland (OR)                   2222   363046.59   365073.66  15644
#   San Francisco (CA)             10271  1635105.56  1646268.56  71998
#   Seattle (WA)                    3471   555194.58   558598.28  24315,
#                       Quantity Ordered  Price Each       Sales   Month
#  City
#   Atlanta (GA)                    5586   936749.37   942530.97   55442
#   Austin (TX)                     3729   605355.42   608632.77   36627
#   Boston (MA)                     7646  1221700.17  1229398.47   75193
#   Dallas (TX)                     5679   948404.97   954175.97   55514
#   Los Angeles (CA)               11220  1785586.60  1796931.20  109915
#   New York City (NY)              9431  1555212.76  1562519.24   93179
#   Portland (ME)                    892   138072.60   138969.81    8820
#   Portland (OR)                   3846   622937.19   626500.08   37602
#   San Francisco (CA)             16941  2723983.02  2739027.58  167345
#   Seattle (WA)                    5664   951724.89   956404.31   56128]

# %%
city_results_Q1
# Out:
#                      Quantity Ordered  Price Each       Sales  Month
# City
#  Atlanta (GA)                    3304   554513.35   557541.20   6396
#  Austin (TX)                     2217   349160.62   350923.75   4300
#  Boston (MA)                     4456   712555.02   716636.49   8512
#  Dallas (TX)                     3338   548402.22   551392.23   6357
#  Los Angeles (CA)                6632  1053384.85  1059757.88  12704
#  New York City (NY)              5519   927763.66   934845.09  10476
#  Portland (ME)                    560    82594.68    83070.58   1041
#  Portland (OR)                   2184   365936.93   368421.86   4205
#  San Francisco (CA)              9917  1665877.66  1673905.74  18977
#  Seattle (WA)                    3208   528335.97   531384.84   6188

# %%
city_results_Q4
# Out:
#                      Quantity Ordered  Price Each       Sales   Month
# City
#  Atlanta (GA)                    5586   936749.37   942530.97   55442
#  Austin (TX)                     3729   605355.42   608632.77   36627
#  Boston (MA)                     7646  1221700.17  1229398.47   75193
#  Dallas (TX)                     5679   948404.97   954175.97   55514
#  Los Angeles (CA)               11220  1785586.60  1796931.20  109915
#  New York City (NY)              9431  1555212.76  1562519.24   93179
#  Portland (ME)                    892   138072.60   138969.81    8820
#  Portland (OR)                   3846   622937.19   626500.08   37602
#  San Francisco (CA)             16941  2723983.02  2739027.58  167345
#  Seattle (WA)                    5664   951724.89   956404.31   56128

# %% [markdown]
# SAN FRANCISCO (CA) seems be the city with the highest number of sales with over 2.7 Million US Dollars in 4th quarter of the year 2019, but let's make sure of our result by using bar graphs:

# %%
keys = [city for city, df in df_merged1.groupby(['City'])]

plt.bar(keys,df_merged1.groupby(['City']).sum()['Sales'])
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.xticks(keys, rotation='vertical', size=8)
plt.show()

# %%
keys = [city for city, df in df_merged2.groupby(['City'])]

plt.bar(keys,df_merged2.groupby(['City']).sum()['Sales'])
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.xticks(keys, rotation='vertical', size=8)
plt.show()

# %%
keys = [city for city, df in df_merged3.groupby(['City'])]

plt.bar(keys,df_merged3.groupby(['City']).sum()['Sales'])
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.xticks(keys, rotation='vertical', size=8)
plt.show()

# %%
keys = [city for city, df in df_merged4.groupby(['City'])]

plt.bar(keys,df_merged4.groupby(['City']).sum()['Sales'])
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.xticks(keys, rotation='vertical', size=8)

plt.show()

# %% [markdown]
# #### Q3. What time should we display advertisements to maximize likelihood of customer's buying product?

# %% [markdown]
# #### 1st Quarter:

# %%
# Use to_datetime to convert Order Date to datetime formate

df_merged1['Hour'] = pd.to_datetime(df_merged1['Order Date']).dt.hour
df_merged1['Minute'] = pd.to_datetime(df_merged1['Order Date']).dt.minute
df_merged1['Count'] = 1
df_merged1.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address   Sales  Month  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  700.00      1
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035   14.95      1
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016   23.98      1
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001  149.99      1
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301   11.99      1
#
#                   City  Hour  Minute  Count
# 0          Boston (MA)    21      25      1
# 1        Portland (OR)    14      15      1
# 2   San Francisco (CA)    13      33      1
# 3     Los Angeles (CA)    20      33      1
# 4          Austin (TX)    11      59      1

# %%
keys = [pair for pair, df in df_merged1.groupby(["Hour"])]

plt.plot(keys, df_merged1.groupby(['Hour']).count()['Count'])
plt.xticks(keys)
plt.grid()
plt.show()

# Observe Peaks and Make Probable Conclusions

# %% [markdown]
# #### 2nd Quarter:

# %%
df_merged2['Hour'] = pd.to_datetime(df_merged2['Order Date']).dt.hour
df_merged2['Minute'] = pd.to_datetime(df_merged2['Order Date']).dt.minute
df_merged2['Count'] = 1
df_merged2.head()
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 121777   176559  Bose SoundSport Headphones                 1       99.99
# 121778   176560                Google Phone                 1      600.00
# 121779   176560            Wired Headphones                 1       11.99
# 121780   176561            Wired Headphones                 1       11.99
#
#             Order Date                      Purchase Address   Sales  Month  \
# 0       04/19/19 08:46          917 1st St, Dallas, TX 75001   23.90      4
# 121777  04/07/19 22:30     682 Chestnut St, Boston, MA 02215   99.99      4
# 121778  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001  600.00      4
# 121779  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001   11.99      4
# 121780  04/30/19 09:27     333 8th St, Los Angeles, CA 90001   11.99      4
#
#                      City  Hour  Minute  Count
# 0             Dallas (TX)     8      46      1
# 121777        Boston (MA)    22      30      1
# 121778   Los Angeles (CA)    14      38      1
# 121779   Los Angeles (CA)    14      38      1
# 121780   Los Angeles (CA)     9      27      1

# %%
keys = [pair for pair, df in df_merged2.groupby(["Hour"])]

plt.plot(keys, df_merged2.groupby(['Hour']).count()['Count'])
plt.xticks(keys)
plt.grid()
plt.show()

# %% [markdown]
# #### 3rd Quarter:

# %%
df_merged3['Hour'] = pd.to_datetime(df_merged3['Order Date']).dt.hour
df_merged3['Minute'] = pd.to_datetime(df_merged3['Order Date']).dt.minute
df_merged3['Count'] = 1
df_merged3.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   222910  Apple Airpods Headphones                 1      150.00
# 1   222911             Flatscreen TV                 1      300.00
# 2   222912     AA Batteries (4-pack)                 1        3.84
# 3   222913     AA Batteries (4-pack)                 1        3.84
# 4   222914    AAA Batteries (4-pack)                 5        2.99
#
#        Order Date                  Purchase Address   Sales  Month  \
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301  150.00      7
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101  300.00      7
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301    3.84      7
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301    3.84      7
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101   14.95      7
#
#             City  Hour  Minute  Count
# 0   Atlanta (GA)    16      51      1
# 1   Seattle (WA)     8      55      1
# 2   Atlanta (GA)    12      41      1
# 3   Atlanta (GA)    10      15      1
# 4   Seattle (WA)     2      13      1

# %%
keys = [pair for pair, df in df_merged3.groupby(["Hour"])]

plt.plot(keys, df_merged3.groupby(['Hour']).count()['Count'])
plt.xticks(keys)
plt.grid()
plt.show()

# %% [markdown]
# #### 4th Quarter:

# %%
df_merged4['Hour'] = pd.to_datetime(df_merged4['Order Date']).dt.hour
df_merged4['Minute'] = pd.to_datetime(df_merged4['Order Date']).dt.minute
df_merged4['Count'] = 1
df_merged4.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each  \
# 0   259358  34in Ultrawide Monitor                 1      379.99
# 1   259359  27in 4K Gaming Monitor                 1      389.99
# 2   259360  AAA Batteries (4-pack)                 2        2.99
# 3   259361        27in FHD Monitor                 1      149.99
# 4   259362        Wired Headphones                 1       11.99
#
#        Order Date                           Purchase Address   Sales  Month  \
# 0  10/28/19 10:56            609 Cherry St, Dallas, TX 75001  379.99     10
# 1  10/28/19 17:26          225 5th St, Los Angeles, CA 90001  389.99     10
# 2  10/24/19 17:20       967 12th St, New York City, NY 10001    5.98     10
# 3  10/14/19 22:26  628 Jefferson St, New York City, NY 10001  149.99     10
# 4  10/07/19 16:10         534 14th St, Los Angeles, CA 90001   11.99     10
#
#                   City  Hour  Minute  Count
# 0          Dallas (TX)    10      56      1
# 1     Los Angeles (CA)    17      26      1
# 2   New York City (NY)    17      20      1
# 3   New York City (NY)    22      26      1
# 4     Los Angeles (CA)    16      10      1

# %%
keys = [pair for pair, df in df_merged4.groupby(["Hour"])]

plt.plot(keys, df_merged4.groupby(['Hour']).count()['Count'])
plt.xticks(keys)
plt.grid()
plt.show()
